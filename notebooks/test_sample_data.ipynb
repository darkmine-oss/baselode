# %%
import pandas as pd

# %%
df = pd.read_csv('demo-viewer-react/app/public/data/gswa/demo_gswa_sample_survey.csv')

# %%
df
# Out:
#        Depth        Dip     Azimuth                        HoleId
# 0        0.0 -67.949997  269.876892       101533ForrestaniaFFD166
# 1        5.0 -67.949997  269.876892       101533ForrestaniaFFD166
# 2       10.0 -67.839996  269.956909       101533ForrestaniaFFD166
# 3       15.0 -67.550003  270.566895       101533ForrestaniaFFD166
# 4       20.0 -67.309998  270.816895       101533ForrestaniaFFD166
# ...      ...        ...         ...                           ...
# 80628  791.0 -72.860001  275.600006  97253ForrestaniaFFD167W2W1W2
# 80629  856.0 -73.750000  293.100006  97253ForrestaniaFFD167W2W1W2
# 80630  912.0 -74.489998  291.100006  97253ForrestaniaFFD167W2W1W2
# 80631  918.0 -74.570000  290.600006  97253ForrestaniaFFD167W2W1W2
# 80632  960.0 -74.110001  292.600006  97253ForrestaniaFFD167W2W1W2
#
# [80633 rows x 4 columns]

# %%
df["HoleId"].nunique()
# Out:
# 414
